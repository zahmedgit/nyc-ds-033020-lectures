# %%
import pandas as pd
pd.set_option('display.max_columns', 300)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('dataset.csv', index_col=0)
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0     200000    2          3         1   30      2      2      2      2
# 1     200000    2          4         2   27     -2     -2     -2     -2
# 2      20000    2          2         2   28      0      0      2      0
# 3      50000    1          2         2   23      0      0      0     -1
# 4      20000    1          2         1   47     -1     -1     -1     -2
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0      2      2     140327     143137     145374     147273     149244
# 1     -2     -2          0          0          0          0          0
# 2      0      0       2937       5696       4144       8168       6894
# 3      0      0      51274      50474      49724      48437      18712
# 4     -2     -2        390        780          0          0          0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0     151973      6600      6000      5860      6000      5000         0
# 1          0         0         0         0         0         0         0
# 2      11424      3353         3      5101         6      6530      8103
# 3      19129      4175     41000     51705       700       718       700
# 4          0       780         0         0         0         0         0
#
#    default payment next month
# 0                           0
# 1                           0
# 2                           1
# 3                           0
# 4                           0

# %%
sns.pairplot(df)

# %%
plt.subplots()

# %%
sns.heatmap(df.corr()[df.corr()>.9])

# %%
df.EDUCATION.unique()
# Out:
# array([3, 4, 2, 1, 5, 6, 0], dtype=int64)

# %%
ed_dict={
    1: 'grad',
    2: 'university',
    3: 'high',
    0: 'other',
    4: 'other',
    5: 'other',
    6: 'other'
}
df.EDUCATION=df.EDUCATION.replace(ed_dict)

# %%
df.MARRIAGE.unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
mar_dict={
    0: 'other',
    1: 'married',
    2: 'single',
    3: 'divorced'
}

df.MARRIAGE=df.MARRIAGE.replace(mar_dict)
