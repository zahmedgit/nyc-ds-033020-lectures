# %% [markdown]
# ## Starting Off
#
# Message me one question you have about APIs. Any question at all

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = 'iiD4cWOR-Fz3fX4le1knTg'
api_key = 'gVojruYHjAZGYpsmLozBDSpP7qswB8zmqcy3mYwvXEIMJEIcx1HMil3rIC297GhpfgYqi2qZfXzVju4h_gcZfFGxLXUNTIXxRlxtIYnvhbTDRAfJ80Oi-xiTDG2QXnYx'

# %%
from  keys  import  client_id, api_key

# %%
print(api_key)
# Out:
# gVojruYHjAZGYpsmLozBDSpP7qswB8zmqcy3mYwvXEIMJEIcx1HMil3rIC297GhpfgYqi2qZfXzVju4h_gcZfFGxLXUNTIXxRlxtIYnvhbTDRAfJ80Oi-xiTDG2QXnYx

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'Pizza'

#where do you want to perform this search
location = 'Queens'

# what is your other parameter you want to search against
attributes = 'hot_and_new'

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "attributes" : attributes,
                "limit": 50
            }

# %%
url_params
# Out:
# {'term': 'Pizza',
#  'location': 'Queens',
#  'attributes': 'hot_and_new',
#  'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
if response.status_code==200:
    print(response.status_code)
else:
    print(response.status_code)
# Out:
# 200

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.text
# Out:
# '{"businesses": [{"id": "vlQwCfdPrgT6w-Xho_4xrA", "alias": "nonnaz-pizzeria-and-restaurant-queens-2", "name": "Nonnaz Pizzeria & Restaurant", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/1JDYBjxNnFuMLVSwM-3E6w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/nonnaz-pizzeria-and-restaurant-queens-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg", "review_count": 7, "categories": [{"alias": "pizza", "title": "Pizza"}], "rating": 4.5, "coordinates": {"latitude": 40.760154, "longitude": -73.9074865}, "transactions": ["pickup", "delivery"], "location": {"address1": "49-14 30th Ave", "address2": null, "address3": "", "city": "Queens", "zip_code": "11377", "country": "US", "state": "NY", "display_address": ["49-14 30th Ave", "Queens, NY 11377"]}, "phone": "+17188061165", "display_phone": "(718) 806-1165", "distance": 5600.473558725632}, {"id": "9KcKA_gwfqWuCG9Ln14P7A", "alias": "public-display-of-affection-brooklyn", "name": "Public Display of Affection", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/RnTZ5IUYylDsPBtcwsDSDA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/public-display-of-affection-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg", "review_count": 13, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "comfortfood", "title": "Comfort Food"}], "rating": 5.0, "coordinates": {"latitude": 40.67741, "longitude": -73.98265}, "transactions": [], "location": {"address1": "669 Union St", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11215", "country": "US", "state": "NY", "display_address": ["669 Union St", "Brooklyn, NY 11215"]}, "phone": "+17186351678", "display_phone": "(718) 635-1678", "distance": 12486.602934614824}, {"id": "IbTOahV7PjkYwVDsGlfseA", "alias": "margari-pizza-new-york", "name": "Margari Pizza", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/9S76679FYDwFYKuiS3SWiw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/margari-pizza-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg", "review_count": 6, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "italian", "title": "Italian"}], "rating": 5.0, "coordinates": {"latitude": 40.758785, "longitude": -73.965338}, "transactions": ["pickup", "delivery"], "location": {"address1": "1072 2nd Ave", "address2": null, "address3": "", "city": "New York", "zip_code": "10022", "country": "US", "state": "NY", "display_address": ["1072 2nd Ave", "New York, NY 10022"]}, "phone": "+12129061929", "display_phone": "(212) 906-1929", "distance": 9953.192520367458}, {"id": "R-ve5GRzP0WlbQvDVI3HKg", "alias": "pane-pasta-new-york", "name": "Pane Pasta", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/_2CPyMfrbo26gQX2lKFQ3Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/pane-pasta-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg", "review_count": 1, "categories": [{"alias": "italian", "title": "Italian"}], "rating": 5.0, "coordinates": {"latitude": 40.73328, "longitude": -73.99905}, "transactions": ["pickup", "delivery"], "location": {"address1": "58 West 8th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10011", "country": "US", "state": "NY", "display_address": ["58 West 8th St", "New York, NY 10011"]}, "phone": "+16468910006", "display_phone": "(646) 891-0006", "distance": 12323.11481665062}, {"id": "qj-5zKQ1D4SuRCG3wSzd0g", "alias": "japan-pizza-den-den-gyoza-sunnyside", "name": "Japan Pizza Den Den Gyoza", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Ab0CfNB8hV0IqOqQHSCY7Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/japan-pizza-den-den-gyoza-sunnyside?adjus ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'vlQwCfdPrgT6w-Xho_4xrA',
#    'alias': 'nonnaz-pizzeria-and-restaurant-queens-2',
#    'name': 'Nonnaz Pizzeria & Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1JDYBjxNnFuMLVSwM-3E6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nonnaz-pizzeria-and-restaurant-queens-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 7,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.760154, 'longitude': -73.9074865},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '49-14 30th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49-14 30th Ave', 'Queens, NY 11377']},
#    'phone': '+17188061165',
#    'display_phone': '(718) 806-1165',
#    'distance': 5600.473558725632},
#   {'id': '9KcKA_gwfqWuCG9Ln14P7A',
#    'alias': 'public-display-of-affection-brooklyn',
#    'name': 'Public Display of Affection',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RnTZ5IUYylDsPBtcwsDSDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/public-display-of-affection-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.67741, 'longitude': -73.98265},
#    'transactions': [],
#    'location': {'address1': '669 Union St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['669 Union St', 'Brooklyn, NY 11215']},
#    'phone': '+17186351678',
#    'display_phone': '(718) 635-1678',
#    'distance': 12486.602934614824},
#   {'id': 'IbTOahV7PjkYwVDsGlfseA',
#    'alias': 'margari-pizza-new-york',
#    'name': 'Margari Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9S76679FYDwFYKuiS3SWiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/margari-pizza-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.758785, 'longitude': -73.965338},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1072 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1072 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12129061929',
#    'display_phone': '(212) 906-1929',
#    'distance': 9953.192520367458},
#   {'id': 'R-ve5GRzP0WlbQvDVI3HKg',
#    'alias': 'pane-pasta-new-york',
#    'name': 'Pane Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_2CPyMfrbo26gQX2lKFQ3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pane-pasta-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73328, 'longitude': -73.99905},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '58 West 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 West 8th St', 'New York, NY 10011']},
#    'phone': '+16468910006',
#    'display_phone': '(646) 891-0006',
#    'distance': 12323.11481665062},
#   {'id': 'qj-5zKQ1D4SuRCG3wSzd0g',
#    'alias': 'japan-pizza-den-den-gyoza-sunnyside',
#    'name': 'Japan Pizza Den Den Gyoza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ab0CfNB8hV0IqOqQHSCY7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/japan-pizza-den-den-gyoza-sunnyside?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 3,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7427046910303,
#     'longitude': -73.9224605740662},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '43-48 42nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-48 42nd St', 'Sunnyside, NY 11104']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5997.080223139142},
#   {'id': 'e4L0hsq6Q96mV2nKQ9CgNQ',
#    'alias': 'tramonti-fifth-ave-new-york-2',
#    'name': 'Tramonti Fifth Ave',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-WR7y4TvoCAeM1147XW0Xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tramonti-fifth-ave-new-york-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 11,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74475, 'longitude': -73.98772},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '2 W 28th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 W 28th St', 'New York, NY 10001']},
#    'phone': '+12124647082',
#    'display_phone': '(212) 464-7082',
#    'distance': 11458.836657637006},
#   {'id': 'PORcMv0MUV-8DLM6tpk-wg',
#    'alias': 'hangry-new-hyde-park',
#    'name': 'Hangry',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bKCV7FiIQRgmA52sqMo6Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hangry-new-hyde-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 60,
#    'categories': [{'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742781, 'longitude': -73.695043},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '725 Hillside Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New Hyde Park',
#     'zip_code': '11040',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['725 Hillside Ave', 'New Hyde Park, NY 11040']},
#    'phone': '+15166297102',
#    'display_phone': '(516) 629-7102',
#    'distance': 13354.719294850565},
#   {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#    'alias': 'rome-to-brooklyn-pizza-and-panzerotti-new-york',
#    'name': 'Rome to Brooklyn, pizza & panzerotti',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kK0siIAWk4yPMmCCjvp5wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-and-panzerotti-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 21,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.711921, 'longitude': -73.942922},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '755 grand st',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['755 grand st', 'New York, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7894.965119908428},
#   {'id': 'BQSPAXJcPw-7Gt2CCrH2Yw',
#    'alias': 'ita-italian-kitchen-jersey-city-2',
#    'name': 'Ita Italian Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3O1x-ptrFbqBCbH5qYNGPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ita-italian-kitchen-jersey-city-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 17,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723524, 'longitude': -74.07016},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '686 Bergen Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['686 Bergen Ave', 'Jersey City, NJ 07304']},
#    'phone': '+12014358380',
#    'display_phone': '(201) 435-8380',
#    'distance': 18341.86544344835},
#   {'id': 'wOBPzCalMjGMxbifFatsrw',
#    'alias': 'il-bel-paese-brooklyn',
#    'name': 'IL Bel Paese',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Lk8eNCjIgG9O0iz8_I2noA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-bel-paese-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7017599753781,
#     'longitude': -73.9233199506998},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '305 Knickerbocker Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['305 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17186280077',
#    'display_phone': '(718) 628-0077',
#    'distance': 6796.355578126075},
#   {'id': 'IUuxH8Q7ek2465F6ENe43A',
#    'alias': 'taco-bell-rego-park',
#    'name': 'Taco Bell',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zYDCAmFt9sMpelq_6XZrFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-rego-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 10,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7296059198506,
#     'longitude': -73.862450234592},
#    'transactions': ['delivery'],
#    'location': {'address1': '9506 63rd Drive',
#     'address2': '',
#     'address3': None,
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9506 63rd Drive', 'Rego Park, NY 11374']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 835.4287450997344},
#   {'id': 'qZ364R1u7E3l6WotUOkLnQ',
#    'alias': 'pie-oh-my-woodland-park',
#    'name': 'PIE OH MY',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zk9odKulwewOQH9o-cf9aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pie-oh-my-woodland-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 3,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.8837, 'longitude': -74.20366},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Woodland Park',
#     'zip_code': '07424',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Woodland Park, NJ 07424']},
#    'phone': '+17186449490',
#    'display_phone': '(718) 644-9490',
#    'distance': 34513.70210634626},
#   {'id': '4oMi-MeyN1dVt-zuEMqdTQ',
#    'alias': 'mani-in-pasta-new-york-3',
#    'name': 'Mani In Pasta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DEz4TXBia9BVwkBExPsdwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mani-in-pasta-new-york-3?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.754887, 'longitude': -73.98962},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '231 W 39th St',
#     'address2': '',
#     'address3': 'The Deco',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 W 39th St', 'The Deco', 'New York, NY 10018']},
#    'phone': '+16469931650',
#    'display_phone': '(646) 993-1650',
#    'distance': 11813.435213401595},
#   {'id': 'eendqrZ9Cp_JisaDtoBU4w',
#    'alias': 'bravo-pizza-staten-island',
#    'name': 'Bravo Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/98GIefvXOn22c6qrv3ebMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravo-pizza-staten-island?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5701278126894,
#     'longitude': -74.108795389156},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '413  New Dorp Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413  New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17183171010',
#    'display_phone': '(718) 317-1010',
#    'distance': 28072.918509476836},
#   {'id': 'WBG-l_bfLmBwR0P36ZFOLg',
#    'alias': 'hong-chun-cheon-cheese-dak-galbi-flushing',
#    'name': 'Hong Chun Cheon Cheese Dak galbi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZLBf8cSLR-woCBrGiE5cRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hong-chun-cheon-cheese-dak-galbi-flushing?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7638809, 'longitude': -73.808914},
#    'transactions': [],
#    'location': {'address1': '156-16 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156-16 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+17188881844',
#    'display_phone': '(718) 888-1844',
#    'distance': 5113.620883228562},
#   {'id': '-KRZr8qtXaJF7gVL-xrM6w',
#    'alias': 'uncle-louies-pizza-montvale',
#    'name': "Uncle Louie's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lQ13dvw_VGpbjnTtI2-Fzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-louies-pizza-montvale?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 41.040611, 'longitude': -74.031044},
#    'transactions': [],
#    'location': {'address1': '15 W Grand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Montvale',
#     'zip_code': '07645',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['15 W Grand Ave', 'Montvale, NJ 07645']},
#    'phone': '+12017469777',
#    'display_phone': '(201) 746-9777',
#    'distance': 37496.707932827536},
#   {'id': 'ihpr2et12Z1eqDd94oLzbg',
#    'alias': 'papi-white-plains',
#    'name': "Papi'",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/htul4laoxg_xNeS1ArLNsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papi-white-plains?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 17,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.0316366, 'longitude': -73.7741697},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Bank St',
#     'address2': None,
#     'address3': None,
#     'city': 'White Plains',
#     'zip_code': '10606',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Bank St', 'White Plains, NY 10606']},
#    'phone': '+19143286535',
#    'display_phone': '(914) 328-6535',
#    'distance': 34026.440444961256},
#   {'id': 'gzRYzr57wh8NmvySbFAioQ',
#    'alias': 'pulia-ristorante-brooklyn-3',
#    'name': 'Pulia Ristorante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_8l8yDlW2p-6pt-vVJl3lA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pulia-ristorante-brooklyn-3?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6669558, 'longitude': -73.9918603},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '548 4th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['548 4th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187881140',
#    'display_phone': '(718) 788-1140',
#    'distance': 13740.312546433044},
#   {'id': 'z0lX40tXQxOHlU26VhLATA',
#    'alias': 'american-brass-long-island-city',
#    'name': 'American Brass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3L2vmRGaTRNGq1pJfMrFSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/american-brass-long-island-city?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 8,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7439708, 'longitude': -73.958493},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '49th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11109',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49th Ave', 'Long Island City, NY 11109']},
#    'phone': '+17188061106',
#    'display_phone': '(718) 806-1106',
#    'distance': 9009.156580274745},
#   {'id': 'kQvwxbFuvRMoj7G5SkmoCw',
#    'alias': 'i-love-panzerotti-east-village-new-york',
#    'name': 'I Love Panzerotti-- East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dWbavKg5sxQDT3HAsU3dzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-love-panzerotti-east-village-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7266801, 'longitude': -73.9835791},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '130 St Marks Pl',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+16465967113',
#    'display_phone': '(646) 596-7113',
#    'distance': 11029.061040158234},
#   {'id': '9qAI3zpjQPL2cf4ak41iGQ',
#    'alias': 'saige-cafe-at-le-havre-whitestone',
#    'name': 'Saige Cafe At Le Havre',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aPJ0BEQysLSP0VZ37bdz8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saige-cafe-at-le-havre-whitestone?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7926827, 'longitude': -73.796176},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '168-68 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168-68 9th Ave', 'Whitestone, NY 11357']},
#    'phone': '+19179941978',
#    'display_phone': '(917) 994-1978',
#    'distance': 8316.227229899267},
#   {'id': 'vwXTY710wucZYxWjxhoQlw',
#    'alias': 'public-pizza-italian-kitchen-yonkers',
#    'name': 'Public Pizza Italian Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y-PlP_VjlPxIior2q2NUgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/public-pizza-italian-kitchen-yonkers?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 14,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.965286, 'longitude': -73.857319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '193 Market St',
#     'address2': '',
#     'address3': None,
#     'city': 'Yonkers',
#     'zip_code': '10710',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['193 Market St', 'Yonkers, NY 10710']},
#    'phone': '+19146527611',
#    'display_phone': '(914) 652-7611',
#    'distance': 26002.333618676646},
#   {'id': '7vqKC--s8iJ37QGitNhkeQ',
#    'alias': 'zanmi-brooklyn-2',
#    'name': 'Zanmi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gjnAYbEfInQrdx1rsTlNSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zanmi-brooklyn-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 18,
#    'categories': [{'alias': 'haitian', 'title': 'Haitian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6579395, 'longitude': -73.9505773},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1206 Nostrand Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1206 Nostrand Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17186761047',
#    'display_phone': '(718) 676-1047',
#    'distance': 11607.511952493971},
#   {'id': 'bfTN46ZuFean1ahYVE3s9Q',
#    'alias': 'the-marilyn-new-york',
#    'name': 'The Marilyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p75Yt7HDI0k1KQcJZxr-nQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marilyn-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747222, 'longitude': -73.98699},
#    'transactions': [],
#    'location': {'address1': '19 W 31st St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 W 31st St', 'New York, NY 10001']},
#    'phone': '+12126159900',
#    'display_phone': '(212) 615-9900',
#    'distance': 11436.370552586292},
#   {'id': '41l-WTeRkc6dy6Zss9MG4w',
#    'alias': 'six-corners-marketplace-new-york',
#    'name': 'Six Corners Marketplace',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JE3Y0FEsmmbURc_OIzY45g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/six-corners-marketplace-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.80125, 'longitude': -73.9681801},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2755 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2755 Broadway', 'New York, NY 10025']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 12433.801215294208},
#   {'id': '3ip8E1YiD6jiIF51-oaXiw',
#    'alias': 'tavola-della-nonna-new-york',
#    'name': 'Tavola Della Nonna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xo96dq6IQZpcUg3eBtC9YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavola-della-nonna-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.77757, 'longitude': -73.98347},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '208 W 70th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 W 70th St', 'New York, NY 10023']},
#    'phone': '+12128758600',
#    'display_phone': '(212) 875-8600',
#    'distance': 12123.812431360613},
#   {'id': 'cF-dEjuELf-m4CWN9zFhjw',
#    'alias': 'taco-bell-cantina-new-york-13',
#    'name': 'Taco Bell Cantina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NVmP1AJiSk2C7WsEx1v8gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-cantina-new-york-13?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.750926, 'longitude': -73.986737},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '976 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['976 6th Ave', 'New York, NY 10018']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11485.921543759065},
#   {'id': 'hUf1EpnxbxFU4gf2nL7H-Q',
#    'alias': 'raku-its-japanese-new-york-2',
#    'name': "Raku it's Japanese",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sYcYRWpDHeP0wRBeF-HMjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-its-japanese-new-york-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 16,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.756591, 'longitude': -73.969306},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '212 East 52nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 East 52nd St', 'New York, NY 10022']},
#    'phone': '+12123553272',
#    'display_phone': '(212) 355-3272',
#    'distance': 10202.14607573553},
#   {'id': 'jFEGRmuZe5fwCugyZnBmyg',
#    'alias': 'exotic-empanadas-new-york',
#    'name': 'Exotic Empanadas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6LgmV1-cKE6JNFY3jVDaLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exotic-empanadas-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 9,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74528, 'longitude': -73.97574},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '635 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['635 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16467070488',
#    'display_phone': '(646) 707-0488',
#    'distance': 10470.87090567895},
#   {'id': 'L949I6aMoUEpaY-dr-SJNw',
#    'alias': 'dragon-sushi-new-york',
#    'name': 'Dragon Sushi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zDYIgyz7NHLDg7g5nGie9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dragon-sushi-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 9,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.811043, 'longitude': -73.958387},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1264 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1264 Amsterdam Ave', 'New York, NY 10027']},
#    'phone': '+16464905254',
#    'display_phone': '(646) 490-5254',
#    'distance': 12543.618965750353},
#   {'id': '3Z95QwfXtxOUdPRjiSVtFw',
#    'alias': 'amira-s-steak-and-chops-hicksville',
#    'name': 'Amira’s Steak & Chops',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7TAK8n1hbu6dWWTU2bophg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amira-s-steak-and-chops-hicksville?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 7,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75889, 'longitude': -73.513534},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '412 S Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Hicksville',
#     'zip_code': '11801',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['412 S Broadway', 'Hicksville, NY 11801']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 28746.823378405454},
#   {'id': '7MPabjQRvQ_IhD3Wfmf-cQ',
#    'alias': 'anna-marias-wine-bar-rye',
#    'name': "Anna Maria's Wine Bar",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anna-marias-wine-bar-rye?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.98354, 'longitude': -73.68513},
#    'transactions': [],
#    'location': {'address1': '53 Purchase St',
#     'address2': None,
#     'address3': None,
#     'city': 'Rye',
#     'zip_code': '10580',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53 Purchase St', 'Rye, NY 10580']},
#    'phone': '+19143056780',
#    'display_phone': '(914) 305-6780',
#    'distance': 31386.18836335289},
#   {'id': 'e5c8jGklVNKoaURcDsVxgQ',
#    'alias': 'curry-up-now-hoboken',
#    'name': 'Curry Up Now',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L2ei7yoBaDnEndYWuA2d0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/curry-up-now-hoboken?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 58,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.737095, 'longitude': -74.030759},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '91 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['91 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12016592879',
#    'display_phone': '(201) 659-2879',
#    'distance': 15003.41880110369},
#   {'id': 'tCZWXOnv_6R7GbmzVAUgHg',
#    'alias': 'something-sweet-brooklyn',
#    'name': 'Something Sweet',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOmTtDaWLS-EZzI-ftbEng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/something-sweet-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.604613, 'longitude': -73.998727},
#    'transactions': [],
#    'location': {'address1': '1976 86th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1976 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17185177337',
#    'display_phone': '(718) 517-7337',
#    'distance': 18719.933183671368},
#   {'id': 'SNTBdiEi55Zvt3qa4AAEJg',
#    'alias': 'sakana-sushi-and-hibachi-steakhouse-staten-island',
#    'name': 'Sakana Sushi & Hibachi Steakhouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2A3iBAhvVfunyW8L8KmZGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakana-sushi-and-hibachi-steakhouse-staten-island?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.589737938998,
#     'longitude': -74.1013584556552},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1657 Richmond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1657 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17189877999',
#    'display_phone': '(718) 987-7999',
#    'distance': 26225.480961449095}],
#  'total': 35,
#  'region': {'center': {'longitude': -73.85284423828125,
#    'latitude': 40.73146603137887}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'vlQwCfdPrgT6w-Xho_4xrA',
#    'alias': 'nonnaz-pizzeria-and-restaurant-queens-2',
#    'name': 'Nonnaz Pizzeria & Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1JDYBjxNnFuMLVSwM-3E6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nonnaz-pizzeria-and-restaurant-queens-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 7,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.760154, 'longitude': -73.9074865},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '49-14 30th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49-14 30th Ave', 'Queens, NY 11377']},
#    'phone': '+17188061165',
#    'display_phone': '(718) 806-1165',
#    'distance': 5600.473558725632},
#   {'id': '9KcKA_gwfqWuCG9Ln14P7A',
#    'alias': 'public-display-of-affection-brooklyn',
#    'name': 'Public Display of Affection',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RnTZ5IUYylDsPBtcwsDSDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/public-display-of-affection-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.67741, 'longitude': -73.98265},
#    'transactions': [],
#    'location': {'address1': '669 Union St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['669 Union St', 'Brooklyn, NY 11215']},
#    'phone': '+17186351678',
#    'display_phone': '(718) 635-1678',
#    'distance': 12486.602934614824},
#   {'id': 'IbTOahV7PjkYwVDsGlfseA',
#    'alias': 'margari-pizza-new-york',
#    'name': 'Margari Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9S76679FYDwFYKuiS3SWiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/margari-pizza-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.758785, 'longitude': -73.965338},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1072 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1072 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12129061929',
#    'display_phone': '(212) 906-1929',
#    'distance': 9953.192520367458},
#   {'id': 'R-ve5GRzP0WlbQvDVI3HKg',
#    'alias': 'pane-pasta-new-york',
#    'name': 'Pane Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_2CPyMfrbo26gQX2lKFQ3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pane-pasta-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73328, 'longitude': -73.99905},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '58 West 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 West 8th St', 'New York, NY 10011']},
#    'phone': '+16468910006',
#    'display_phone': '(646) 891-0006',
#    'distance': 12323.11481665062},
#   {'id': 'qj-5zKQ1D4SuRCG3wSzd0g',
#    'alias': 'japan-pizza-den-den-gyoza-sunnyside',
#    'name': 'Japan Pizza Den Den Gyoza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ab0CfNB8hV0IqOqQHSCY7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/japan-pizza-den-den-gyoza-sunnyside?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 3,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7427046910303,
#     'longitude': -73.9224605740662},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '43-48 42nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-48 42nd St', 'Sunnyside, NY 11104']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5997.080223139142},
#   {'id': 'e4L0hsq6Q96mV2nKQ9CgNQ',
#    'alias': 'tramonti-fifth-ave-new-york-2',
#    'name': 'Tramonti Fifth Ave',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-WR7y4TvoCAeM1147XW0Xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tramonti-fifth-ave-new-york-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 11,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74475, 'longitude': -73.98772},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '2 W 28th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 W 28th St', 'New York, NY 10001']},
#    'phone': '+12124647082',
#    'display_phone': '(212) 464-7082',
#    'distance': 11458.836657637006},
#   {'id': 'PORcMv0MUV-8DLM6tpk-wg',
#    'alias': 'hangry-new-hyde-park',
#    'name': 'Hangry',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bKCV7FiIQRgmA52sqMo6Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hangry-new-hyde-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 60,
#    'categories': [{'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742781, 'longitude': -73.695043},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '725 Hillside Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New Hyde Park',
#     'zip_code': '11040',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['725 Hillside Ave', 'New Hyde Park, NY 11040']},
#    'phone': '+15166297102',
#    'display_phone': '(516) 629-7102',
#    'distance': 13354.719294850565},
#   {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#    'alias': 'rome-to-brooklyn-pizza-and-panzerotti-new-york',
#    'name': 'Rome to Brooklyn, pizza & panzerotti',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kK0siIAWk4yPMmCCjvp5wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-and-panzerotti-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 21,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.711921, 'longitude': -73.942922},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '755 grand st',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['755 grand st', 'New York, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7894.965119908428},
#   {'id': 'BQSPAXJcPw-7Gt2CCrH2Yw',
#    'alias': 'ita-italian-kitchen-jersey-city-2',
#    'name': 'Ita Italian Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3O1x-ptrFbqBCbH5qYNGPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ita-italian-kitchen-jersey-city-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 17,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723524, 'longitude': -74.07016},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '686 Bergen Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['686 Bergen Ave', 'Jersey City, NJ 07304']},
#    'phone': '+12014358380',
#    'display_phone': '(201) 435-8380',
#    'distance': 18341.86544344835},
#   {'id': 'wOBPzCalMjGMxbifFatsrw',
#    'alias': 'il-bel-paese-brooklyn',
#    'name': 'IL Bel Paese',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Lk8eNCjIgG9O0iz8_I2noA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-bel-paese-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7017599753781,
#     'longitude': -73.9233199506998},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '305 Knickerbocker Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['305 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17186280077',
#    'display_phone': '(718) 628-0077',
#    'distance': 6796.355578126075},
#   {'id': 'IUuxH8Q7ek2465F6ENe43A',
#    'alias': 'taco-bell-rego-park',
#    'name': 'Taco Bell',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zYDCAmFt9sMpelq_6XZrFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-rego-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 10,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7296059198506,
#     'longitude': -73.862450234592},
#    'transactions': ['delivery'],
#    'location': {'address1': '9506 63rd Drive',
#     'address2': '',
#     'address3': None,
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9506 63rd Drive', 'Rego Park, NY 11374']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 835.4287450997344},
#   {'id': 'qZ364R1u7E3l6WotUOkLnQ',
#    'alias': 'pie-oh-my-woodland-park',
#    'name': 'PIE OH MY',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zk9odKulwewOQH9o-cf9aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pie-oh-my-woodland-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 3,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.8837, 'longitude': -74.20366},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Woodland Park',
#     'zip_code': '07424',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Woodland Park, NJ 07424']},
#    'phone': '+17186449490',
#    'display_phone': '(718) 644-9490',
#    'distance': 34513.70210634626},
#   {'id': '4oMi-MeyN1dVt-zuEMqdTQ',
#    'alias': 'mani-in-pasta-new-york-3',
#    'name': 'Mani In Pasta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DEz4TXBia9BVwkBExPsdwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mani-in-pasta-new-york-3?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.754887, 'longitude': -73.98962},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '231 W 39th St',
#     'address2': '',
#     'address3': 'The Deco',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 W 39th St', 'The Deco', 'New York, NY 10018']},
#    'phone': '+16469931650',
#    'display_phone': '(646) 993-1650',
#    'distance': 11813.435213401595},
#   {'id': 'eendqrZ9Cp_JisaDtoBU4w',
#    'alias': 'bravo-pizza-staten-island',
#    'name': 'Bravo Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/98GIefvXOn22c6qrv3ebMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravo-pizza-staten-island?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5701278126894,
#     'longitude': -74.108795389156},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '413  New Dorp Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413  New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17183171010',
#    'display_phone': '(718) 317-1010',
#    'distance': 28072.918509476836},
#   {'id': 'WBG-l_bfLmBwR0P36ZFOLg',
#    'alias': 'hong-chun-cheon-cheese-dak-galbi-flushing',
#    'name': 'Hong Chun Cheon Cheese Dak galbi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZLBf8cSLR-woCBrGiE5cRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hong-chun-cheon-cheese-dak-galbi-flushing?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7638809, 'longitude': -73.808914},
#    'transactions': [],
#    'location': {'address1': '156-16 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156-16 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+17188881844',
#    'display_phone': '(718) 888-1844',
#    'distance': 5113.620883228562},
#   {'id': '-KRZr8qtXaJF7gVL-xrM6w',
#    'alias': 'uncle-louies-pizza-montvale',
#    'name': "Uncle Louie's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lQ13dvw_VGpbjnTtI2-Fzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-louies-pizza-montvale?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 41.040611, 'longitude': -74.031044},
#    'transactions': [],
#    'location': {'address1': '15 W Grand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Montvale',
#     'zip_code': '07645',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['15 W Grand Ave', 'Montvale, NJ 07645']},
#    'phone': '+12017469777',
#    'display_phone': '(201) 746-9777',
#    'distance': 37496.707932827536},
#   {'id': 'ihpr2et12Z1eqDd94oLzbg',
#    'alias': 'papi-white-plains',
#    'name': "Papi'",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/htul4laoxg_xNeS1ArLNsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papi-white-plains?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 17,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.0316366, 'longitude': -73.7741697},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Bank St',
#     'address2': None,
#     'address3': None,
#     'city': 'White Plains',
#     'zip_code': '10606',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Bank St', 'White Plains, NY 10606']},
#    'phone': '+19143286535',
#    'display_phone': '(914) 328-6535',
#    'distance': 34026.440444961256},
#   {'id': 'gzRYzr57wh8NmvySbFAioQ',
#    'alias': 'pulia-ristorante-brooklyn-3',
#    'name': 'Pulia Ristorante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_8l8yDlW2p-6pt-vVJl3lA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pulia-ristorante-brooklyn-3?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6669558, 'longitude': -73.9918603},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '548 4th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['548 4th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187881140',
#    'display_phone': '(718) 788-1140',
#    'distance': 13740.312546433044},
#   {'id': 'z0lX40tXQxOHlU26VhLATA',
#    'alias': 'american-brass-long-island-city',
#    'name': 'American Brass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3L2vmRGaTRNGq1pJfMrFSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/american-brass-long-island-city?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 8,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7439708, 'longitude': -73.958493},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '49th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11109',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49th Ave', 'Long Island City, NY 11109']},
#    'phone': '+17188061106',
#    'display_phone': '(718) 806-1106',
#    'distance': 9009.156580274745},
#   {'id': 'kQvwxbFuvRMoj7G5SkmoCw',
#    'alias': 'i-love-panzerotti-east-village-new-york',
#    'name': 'I Love Panzerotti-- East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dWbavKg5sxQDT3HAsU3dzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-love-panzerotti-east-village-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7266801, 'longitude': -73.9835791},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '130 St Marks Pl',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+16465967113',
#    'display_phone': '(646) 596-7113',
#    'distance': 11029.061040158234},
#   {'id': '9qAI3zpjQPL2cf4ak41iGQ',
#    'alias': 'saige-cafe-at-le-havre-whitestone',
#    'name': 'Saige Cafe At Le Havre',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aPJ0BEQysLSP0VZ37bdz8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saige-cafe-at-le-havre-whitestone?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7926827, 'longitude': -73.796176},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '168-68 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168-68 9th Ave', 'Whitestone, NY 11357']},
#    'phone': '+19179941978',
#    'display_phone': '(917) 994-1978',
#    'distance': 8316.227229899267},
#   {'id': 'vwXTY710wucZYxWjxhoQlw',
#    'alias': 'public-pizza-italian-kitchen-yonkers',
#    'name': 'Public Pizza Italian Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y-PlP_VjlPxIior2q2NUgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/public-pizza-italian-kitchen-yonkers?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 14,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.965286, 'longitude': -73.857319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '193 Market St',
#     'address2': '',
#     'address3': None,
#     'city': 'Yonkers',
#     'zip_code': '10710',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['193 Market St', 'Yonkers, NY 10710']},
#    'phone': '+19146527611',
#    'display_phone': '(914) 652-7611',
#    'distance': 26002.333618676646},
#   {'id': '7vqKC--s8iJ37QGitNhkeQ',
#    'alias': 'zanmi-brooklyn-2',
#    'name': 'Zanmi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gjnAYbEfInQrdx1rsTlNSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zanmi-brooklyn-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 18,
#    'categories': [{'alias': 'haitian', 'title': 'Haitian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6579395, 'longitude': -73.9505773},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1206 Nostrand Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1206 Nostrand Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17186761047',
#    'display_phone': '(718) 676-1047',
#    'distance': 11607.511952493971},
#   {'id': 'bfTN46ZuFean1ahYVE3s9Q',
#    'alias': 'the-marilyn-new-york',
#    'name': 'The Marilyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p75Yt7HDI0k1KQcJZxr-nQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marilyn-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747222, 'longitude': -73.98699},
#    'transactions': [],
#    'location': {'address1': '19 W 31st St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 W 31st St', 'New York, NY 10001']},
#    'phone': '+12126159900',
#    'display_phone': '(212) 615-9900',
#    'distance': 11436.370552586292},
#   {'id': '41l-WTeRkc6dy6Zss9MG4w',
#    'alias': 'six-corners-marketplace-new-york',
#    'name': 'Six Corners Marketplace',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JE3Y0FEsmmbURc_OIzY45g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/six-corners-marketplace-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.80125, 'longitude': -73.9681801},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2755 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2755 Broadway', 'New York, NY 10025']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 12433.801215294208},
#   {'id': '3ip8E1YiD6jiIF51-oaXiw',
#    'alias': 'tavola-della-nonna-new-york',
#    'name': 'Tavola Della Nonna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xo96dq6IQZpcUg3eBtC9YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavola-della-nonna-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.77757, 'longitude': -73.98347},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '208 W 70th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 W 70th St', 'New York, NY 10023']},
#    'phone': '+12128758600',
#    'display_phone': '(212) 875-8600',
#    'distance': 12123.812431360613},
#   {'id': 'cF-dEjuELf-m4CWN9zFhjw',
#    'alias': 'taco-bell-cantina-new-york-13',
#    'name': 'Taco Bell Cantina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NVmP1AJiSk2C7WsEx1v8gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-cantina-new-york-13?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.750926, 'longitude': -73.986737},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '976 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['976 6th Ave', 'New York, NY 10018']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11485.921543759065},
#   {'id': 'hUf1EpnxbxFU4gf2nL7H-Q',
#    'alias': 'raku-its-japanese-new-york-2',
#    'name': "Raku it's Japanese",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sYcYRWpDHeP0wRBeF-HMjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-its-japanese-new-york-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 16,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.756591, 'longitude': -73.969306},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '212 East 52nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 East 52nd St', 'New York, NY 10022']},
#    'phone': '+12123553272',
#    'display_phone': '(212) 355-3272',
#    'distance': 10202.14607573553},
#   {'id': 'jFEGRmuZe5fwCugyZnBmyg',
#    'alias': 'exotic-empanadas-new-york',
#    'name': 'Exotic Empanadas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6LgmV1-cKE6JNFY3jVDaLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exotic-empanadas-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 9,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74528, 'longitude': -73.97574},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '635 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['635 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16467070488',
#    'display_phone': '(646) 707-0488',
#    'distance': 10470.87090567895},
#   {'id': 'L949I6aMoUEpaY-dr-SJNw',
#    'alias': 'dragon-sushi-new-york',
#    'name': 'Dragon Sushi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zDYIgyz7NHLDg7g5nGie9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dragon-sushi-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 9,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.811043, 'longitude': -73.958387},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1264 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1264 Amsterdam Ave', 'New York, NY 10027']},
#    'phone': '+16464905254',
#    'display_phone': '(646) 490-5254',
#    'distance': 12543.618965750353},
#   {'id': '3Z95QwfXtxOUdPRjiSVtFw',
#    'alias': 'amira-s-steak-and-chops-hicksville',
#    'name': 'Amira’s Steak & Chops',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7TAK8n1hbu6dWWTU2bophg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amira-s-steak-and-chops-hicksville?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 7,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75889, 'longitude': -73.513534},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '412 S Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Hicksville',
#     'zip_code': '11801',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['412 S Broadway', 'Hicksville, NY 11801']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 28746.823378405454},
#   {'id': '7MPabjQRvQ_IhD3Wfmf-cQ',
#    'alias': 'anna-marias-wine-bar-rye',
#    'name': "Anna Maria's Wine Bar",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anna-marias-wine-bar-rye?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.98354, 'longitude': -73.68513},
#    'transactions': [],
#    'location': {'address1': '53 Purchase St',
#     'address2': None,
#     'address3': None,
#     'city': 'Rye',
#     'zip_code': '10580',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53 Purchase St', 'Rye, NY 10580']},
#    'phone': '+19143056780',
#    'display_phone': '(914) 305-6780',
#    'distance': 31386.18836335289},
#   {'id': 'e5c8jGklVNKoaURcDsVxgQ',
#    'alias': 'curry-up-now-hoboken',
#    'name': 'Curry Up Now',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L2ei7yoBaDnEndYWuA2d0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/curry-up-now-hoboken?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 58,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.737095, 'longitude': -74.030759},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '91 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['91 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12016592879',
#    'display_phone': '(201) 659-2879',
#    'distance': 15003.41880110369},
#   {'id': 'tCZWXOnv_6R7GbmzVAUgHg',
#    'alias': 'something-sweet-brooklyn',
#    'name': 'Something Sweet',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOmTtDaWLS-EZzI-ftbEng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/something-sweet-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.604613, 'longitude': -73.998727},
#    'transactions': [],
#    'location': {'address1': '1976 86th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1976 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17185177337',
#    'display_phone': '(718) 517-7337',
#    'distance': 18719.933183671368},
#   {'id': 'SNTBdiEi55Zvt3qa4AAEJg',
#    'alias': 'sakana-sushi-and-hibachi-steakhouse-staten-island',
#    'name': 'Sakana Sushi & Hibachi Steakhouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2A3iBAhvVfunyW8L8KmZGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakana-sushi-and-hibachi-steakhouse-staten-island?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.589737938998,
#     'longitude': -74.1013584556552},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1657 Richmond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1657 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17189877999',
#    'display_phone': '(718) 987-7999',
#    'distance': 26225.480961449095}],
#  'total': 35,
#  'region': {'center': {'longitude': -73.85284423828125,
#    'latitude': 40.73146603137887}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = json.loads(response.text)

# %%
data
# Out:
# {'businesses': [{'id': 'vlQwCfdPrgT6w-Xho_4xrA',
#    'alias': 'nonnaz-pizzeria-and-restaurant-queens-2',
#    'name': 'Nonnaz Pizzeria & Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1JDYBjxNnFuMLVSwM-3E6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nonnaz-pizzeria-and-restaurant-queens-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 7,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.760154, 'longitude': -73.9074865},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '49-14 30th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49-14 30th Ave', 'Queens, NY 11377']},
#    'phone': '+17188061165',
#    'display_phone': '(718) 806-1165',
#    'distance': 5600.473558725632},
#   {'id': '9KcKA_gwfqWuCG9Ln14P7A',
#    'alias': 'public-display-of-affection-brooklyn',
#    'name': 'Public Display of Affection',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RnTZ5IUYylDsPBtcwsDSDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/public-display-of-affection-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.67741, 'longitude': -73.98265},
#    'transactions': [],
#    'location': {'address1': '669 Union St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['669 Union St', 'Brooklyn, NY 11215']},
#    'phone': '+17186351678',
#    'display_phone': '(718) 635-1678',
#    'distance': 12486.602934614824},
#   {'id': 'IbTOahV7PjkYwVDsGlfseA',
#    'alias': 'margari-pizza-new-york',
#    'name': 'Margari Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9S76679FYDwFYKuiS3SWiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/margari-pizza-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.758785, 'longitude': -73.965338},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1072 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1072 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12129061929',
#    'display_phone': '(212) 906-1929',
#    'distance': 9953.192520367458},
#   {'id': 'R-ve5GRzP0WlbQvDVI3HKg',
#    'alias': 'pane-pasta-new-york',
#    'name': 'Pane Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_2CPyMfrbo26gQX2lKFQ3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pane-pasta-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 1,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73328, 'longitude': -73.99905},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '58 West 8th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 West 8th St', 'New York, NY 10011']},
#    'phone': '+16468910006',
#    'display_phone': '(646) 891-0006',
#    'distance': 12323.11481665062},
#   {'id': 'qj-5zKQ1D4SuRCG3wSzd0g',
#    'alias': 'japan-pizza-den-den-gyoza-sunnyside',
#    'name': 'Japan Pizza Den Den Gyoza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ab0CfNB8hV0IqOqQHSCY7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/japan-pizza-den-den-gyoza-sunnyside?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 3,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7427046910303,
#     'longitude': -73.9224605740662},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '43-48 42nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-48 42nd St', 'Sunnyside, NY 11104']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5997.080223139142},
#   {'id': 'e4L0hsq6Q96mV2nKQ9CgNQ',
#    'alias': 'tramonti-fifth-ave-new-york-2',
#    'name': 'Tramonti Fifth Ave',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-WR7y4TvoCAeM1147XW0Xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tramonti-fifth-ave-new-york-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 11,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74475, 'longitude': -73.98772},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '2 W 28th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2 W 28th St', 'New York, NY 10001']},
#    'phone': '+12124647082',
#    'display_phone': '(212) 464-7082',
#    'distance': 11458.836657637006},
#   {'id': 'PORcMv0MUV-8DLM6tpk-wg',
#    'alias': 'hangry-new-hyde-park',
#    'name': 'Hangry',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bKCV7FiIQRgmA52sqMo6Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hangry-new-hyde-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 60,
#    'categories': [{'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742781, 'longitude': -73.695043},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '725 Hillside Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New Hyde Park',
#     'zip_code': '11040',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['725 Hillside Ave', 'New Hyde Park, NY 11040']},
#    'phone': '+15166297102',
#    'display_phone': '(516) 629-7102',
#    'distance': 13354.719294850565},
#   {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#    'alias': 'rome-to-brooklyn-pizza-and-panzerotti-new-york',
#    'name': 'Rome to Brooklyn, pizza & panzerotti',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kK0siIAWk4yPMmCCjvp5wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-and-panzerotti-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 21,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.711921, 'longitude': -73.942922},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '755 grand st',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['755 grand st', 'New York, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7894.965119908428},
#   {'id': 'BQSPAXJcPw-7Gt2CCrH2Yw',
#    'alias': 'ita-italian-kitchen-jersey-city-2',
#    'name': 'Ita Italian Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3O1x-ptrFbqBCbH5qYNGPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ita-italian-kitchen-jersey-city-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 17,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723524, 'longitude': -74.07016},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '686 Bergen Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jersey City',
#     'zip_code': '07304',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['686 Bergen Ave', 'Jersey City, NJ 07304']},
#    'phone': '+12014358380',
#    'display_phone': '(201) 435-8380',
#    'distance': 18341.86544344835},
#   {'id': 'wOBPzCalMjGMxbifFatsrw',
#    'alias': 'il-bel-paese-brooklyn',
#    'name': 'IL Bel Paese',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Lk8eNCjIgG9O0iz8_I2noA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/il-bel-paese-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7017599753781,
#     'longitude': -73.9233199506998},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '305 Knickerbocker Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['305 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17186280077',
#    'display_phone': '(718) 628-0077',
#    'distance': 6796.355578126075},
#   {'id': 'IUuxH8Q7ek2465F6ENe43A',
#    'alias': 'taco-bell-rego-park',
#    'name': 'Taco Bell',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zYDCAmFt9sMpelq_6XZrFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-rego-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 10,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7296059198506,
#     'longitude': -73.862450234592},
#    'transactions': ['delivery'],
#    'location': {'address1': '9506 63rd Drive',
#     'address2': '',
#     'address3': None,
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9506 63rd Drive', 'Rego Park, NY 11374']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 835.4287450997344},
#   {'id': 'qZ364R1u7E3l6WotUOkLnQ',
#    'alias': 'pie-oh-my-woodland-park',
#    'name': 'PIE OH MY',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zk9odKulwewOQH9o-cf9aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pie-oh-my-woodland-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 3,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.8837, 'longitude': -74.20366},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Woodland Park',
#     'zip_code': '07424',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Woodland Park, NJ 07424']},
#    'phone': '+17186449490',
#    'display_phone': '(718) 644-9490',
#    'distance': 34513.70210634626},
#   {'id': '4oMi-MeyN1dVt-zuEMqdTQ',
#    'alias': 'mani-in-pasta-new-york-3',
#    'name': 'Mani In Pasta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DEz4TXBia9BVwkBExPsdwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mani-in-pasta-new-york-3?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.754887, 'longitude': -73.98962},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '231 W 39th St',
#     'address2': '',
#     'address3': 'The Deco',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 W 39th St', 'The Deco', 'New York, NY 10018']},
#    'phone': '+16469931650',
#    'display_phone': '(646) 993-1650',
#    'distance': 11813.435213401595},
#   {'id': 'eendqrZ9Cp_JisaDtoBU4w',
#    'alias': 'bravo-pizza-staten-island',
#    'name': 'Bravo Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/98GIefvXOn22c6qrv3ebMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravo-pizza-staten-island?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5701278126894,
#     'longitude': -74.108795389156},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '413  New Dorp Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413  New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17183171010',
#    'display_phone': '(718) 317-1010',
#    'distance': 28072.918509476836},
#   {'id': 'WBG-l_bfLmBwR0P36ZFOLg',
#    'alias': 'hong-chun-cheon-cheese-dak-galbi-flushing',
#    'name': 'Hong Chun Cheon Cheese Dak galbi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZLBf8cSLR-woCBrGiE5cRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hong-chun-cheon-cheese-dak-galbi-flushing?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7638809, 'longitude': -73.808914},
#    'transactions': [],
#    'location': {'address1': '156-16 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156-16 Northern Blvd', 'Flushing, NY 11354']},
#    'phone': '+17188881844',
#    'display_phone': '(718) 888-1844',
#    'distance': 5113.620883228562},
#   {'id': '-KRZr8qtXaJF7gVL-xrM6w',
#    'alias': 'uncle-louies-pizza-montvale',
#    'name': "Uncle Louie's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lQ13dvw_VGpbjnTtI2-Fzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-louies-pizza-montvale?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 41.040611, 'longitude': -74.031044},
#    'transactions': [],
#    'location': {'address1': '15 W Grand Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Montvale',
#     'zip_code': '07645',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['15 W Grand Ave', 'Montvale, NJ 07645']},
#    'phone': '+12017469777',
#    'display_phone': '(201) 746-9777',
#    'distance': 37496.707932827536},
#   {'id': 'ihpr2et12Z1eqDd94oLzbg',
#    'alias': 'papi-white-plains',
#    'name': "Papi'",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/htul4laoxg_xNeS1ArLNsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papi-white-plains?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 17,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.0316366, 'longitude': -73.7741697},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Bank St',
#     'address2': None,
#     'address3': None,
#     'city': 'White Plains',
#     'zip_code': '10606',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Bank St', 'White Plains, NY 10606']},
#    'phone': '+19143286535',
#    'display_phone': '(914) 328-6535',
#    'distance': 34026.440444961256},
#   {'id': 'gzRYzr57wh8NmvySbFAioQ',
#    'alias': 'pulia-ristorante-brooklyn-3',
#    'name': 'Pulia Ristorante',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_8l8yDlW2p-6pt-vVJl3lA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pulia-ristorante-brooklyn-3?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6669558, 'longitude': -73.9918603},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'location': {'address1': '548 4th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['548 4th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187881140',
#    'display_phone': '(718) 788-1140',
#    'distance': 13740.312546433044},
#   {'id': 'z0lX40tXQxOHlU26VhLATA',
#    'alias': 'american-brass-long-island-city',
#    'name': 'American Brass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3L2vmRGaTRNGq1pJfMrFSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/american-brass-long-island-city?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 8,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7439708, 'longitude': -73.958493},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '49th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11109',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49th Ave', 'Long Island City, NY 11109']},
#    'phone': '+17188061106',
#    'display_phone': '(718) 806-1106',
#    'distance': 9009.156580274745},
#   {'id': 'kQvwxbFuvRMoj7G5SkmoCw',
#    'alias': 'i-love-panzerotti-east-village-new-york',
#    'name': 'I Love Panzerotti-- East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dWbavKg5sxQDT3HAsU3dzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-love-panzerotti-east-village-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 8,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7266801, 'longitude': -73.9835791},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '130 St Marks Pl',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 St Marks Pl', 'New York, NY 10009']},
#    'phone': '+16465967113',
#    'display_phone': '(646) 596-7113',
#    'distance': 11029.061040158234},
#   {'id': '9qAI3zpjQPL2cf4ak41iGQ',
#    'alias': 'saige-cafe-at-le-havre-whitestone',
#    'name': 'Saige Cafe At Le Havre',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aPJ0BEQysLSP0VZ37bdz8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saige-cafe-at-le-havre-whitestone?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 1,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7926827, 'longitude': -73.796176},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '168-68 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168-68 9th Ave', 'Whitestone, NY 11357']},
#    'phone': '+19179941978',
#    'display_phone': '(917) 994-1978',
#    'distance': 8316.227229899267},
#   {'id': 'vwXTY710wucZYxWjxhoQlw',
#    'alias': 'public-pizza-italian-kitchen-yonkers',
#    'name': 'Public Pizza Italian Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y-PlP_VjlPxIior2q2NUgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/public-pizza-italian-kitchen-yonkers?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 14,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.965286, 'longitude': -73.857319},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '193 Market St',
#     'address2': '',
#     'address3': None,
#     'city': 'Yonkers',
#     'zip_code': '10710',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['193 Market St', 'Yonkers, NY 10710']},
#    'phone': '+19146527611',
#    'display_phone': '(914) 652-7611',
#    'distance': 26002.333618676646},
#   {'id': '7vqKC--s8iJ37QGitNhkeQ',
#    'alias': 'zanmi-brooklyn-2',
#    'name': 'Zanmi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gjnAYbEfInQrdx1rsTlNSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zanmi-brooklyn-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 18,
#    'categories': [{'alias': 'haitian', 'title': 'Haitian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6579395, 'longitude': -73.9505773},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1206 Nostrand Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1206 Nostrand Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17186761047',
#    'display_phone': '(718) 676-1047',
#    'distance': 11607.511952493971},
#   {'id': 'bfTN46ZuFean1ahYVE3s9Q',
#    'alias': 'the-marilyn-new-york',
#    'name': 'The Marilyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p75Yt7HDI0k1KQcJZxr-nQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-marilyn-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747222, 'longitude': -73.98699},
#    'transactions': [],
#    'location': {'address1': '19 W 31st St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 W 31st St', 'New York, NY 10001']},
#    'phone': '+12126159900',
#    'display_phone': '(212) 615-9900',
#    'distance': 11436.370552586292},
#   {'id': '41l-WTeRkc6dy6Zss9MG4w',
#    'alias': 'six-corners-marketplace-new-york',
#    'name': 'Six Corners Marketplace',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JE3Y0FEsmmbURc_OIzY45g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/six-corners-marketplace-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.80125, 'longitude': -73.9681801},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2755 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2755 Broadway', 'New York, NY 10025']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 12433.801215294208},
#   {'id': '3ip8E1YiD6jiIF51-oaXiw',
#    'alias': 'tavola-della-nonna-new-york',
#    'name': 'Tavola Della Nonna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xo96dq6IQZpcUg3eBtC9YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavola-della-nonna-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.77757, 'longitude': -73.98347},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '208 W 70th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 W 70th St', 'New York, NY 10023']},
#    'phone': '+12128758600',
#    'display_phone': '(212) 875-8600',
#    'distance': 12123.812431360613},
#   {'id': 'cF-dEjuELf-m4CWN9zFhjw',
#    'alias': 'taco-bell-cantina-new-york-13',
#    'name': 'Taco Bell Cantina',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NVmP1AJiSk2C7WsEx1v8gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-bell-cantina-new-york-13?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.750926, 'longitude': -73.986737},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '976 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['976 6th Ave', 'New York, NY 10018']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11485.921543759065},
#   {'id': 'hUf1EpnxbxFU4gf2nL7H-Q',
#    'alias': 'raku-its-japanese-new-york-2',
#    'name': "Raku it's Japanese",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sYcYRWpDHeP0wRBeF-HMjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-its-japanese-new-york-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 16,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.756591, 'longitude': -73.969306},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '212 East 52nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 East 52nd St', 'New York, NY 10022']},
#    'phone': '+12123553272',
#    'display_phone': '(212) 355-3272',
#    'distance': 10202.14607573553},
#   {'id': 'jFEGRmuZe5fwCugyZnBmyg',
#    'alias': 'exotic-empanadas-new-york',
#    'name': 'Exotic Empanadas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6LgmV1-cKE6JNFY3jVDaLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exotic-empanadas-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 9,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'empanadas', 'title': 'Empanadas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74528, 'longitude': -73.97574},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '635 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['635 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16467070488',
#    'display_phone': '(646) 707-0488',
#    'distance': 10470.87090567895},
#   {'id': 'L949I6aMoUEpaY-dr-SJNw',
#    'alias': 'dragon-sushi-new-york',
#    'name': 'Dragon Sushi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zDYIgyz7NHLDg7g5nGie9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dragon-sushi-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 9,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.811043, 'longitude': -73.958387},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1264 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1264 Amsterdam Ave', 'New York, NY 10027']},
#    'phone': '+16464905254',
#    'display_phone': '(646) 490-5254',
#    'distance': 12543.618965750353},
#   {'id': '3Z95QwfXtxOUdPRjiSVtFw',
#    'alias': 'amira-s-steak-and-chops-hicksville',
#    'name': 'Amira’s Steak & Chops',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7TAK8n1hbu6dWWTU2bophg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amira-s-steak-and-chops-hicksville?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 7,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75889, 'longitude': -73.513534},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '412 S Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Hicksville',
#     'zip_code': '11801',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['412 S Broadway', 'Hicksville, NY 11801']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 28746.823378405454},
#   {'id': '7MPabjQRvQ_IhD3Wfmf-cQ',
#    'alias': 'anna-marias-wine-bar-rye',
#    'name': "Anna Maria's Wine Bar",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anna-marias-wine-bar-rye?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.98354, 'longitude': -73.68513},
#    'transactions': [],
#    'location': {'address1': '53 Purchase St',
#     'address2': None,
#     'address3': None,
#     'city': 'Rye',
#     'zip_code': '10580',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53 Purchase St', 'Rye, NY 10580']},
#    'phone': '+19143056780',
#    'display_phone': '(914) 305-6780',
#    'distance': 31386.18836335289},
#   {'id': 'e5c8jGklVNKoaURcDsVxgQ',
#    'alias': 'curry-up-now-hoboken',
#    'name': 'Curry Up Now',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L2ei7yoBaDnEndYWuA2d0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/curry-up-now-hoboken?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 58,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.737095, 'longitude': -74.030759},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '91 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['91 Washington St', 'Hoboken, NJ 07030']},
#    'phone': '+12016592879',
#    'display_phone': '(201) 659-2879',
#    'distance': 15003.41880110369},
#   {'id': 'tCZWXOnv_6R7GbmzVAUgHg',
#    'alias': 'something-sweet-brooklyn',
#    'name': 'Something Sweet',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOmTtDaWLS-EZzI-ftbEng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/something-sweet-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 6,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.604613, 'longitude': -73.998727},
#    'transactions': [],
#    'location': {'address1': '1976 86th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1976 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17185177337',
#    'display_phone': '(718) 517-7337',
#    'distance': 18719.933183671368},
#   {'id': 'SNTBdiEi55Zvt3qa4AAEJg',
#    'alias': 'sakana-sushi-and-hibachi-steakhouse-staten-island',
#    'name': 'Sakana Sushi & Hibachi Steakhouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2A3iBAhvVfunyW8L8KmZGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakana-sushi-and-hibachi-steakhouse-staten-island?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#    'review_count': 13,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.589737938998,
#     'longitude': -74.1013584556552},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1657 Richmond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1657 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17189877999',
#    'display_phone': '(718) 987-7999',
#    'distance': 26225.480961449095}],
#  'total': 35,
#  'region': {'center': {'longitude': -73.85284423828125,
#    'latitude': 40.73146603137887}}}

# %%
#What are the keys in this dictionary and the datatypes of their values.
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
for k,value in data.items():
    print(k)
    print(type(value))
# Out:
# businesses
# <class 'list'>
# total
# <class 'int'>
# region
# <class 'dict'>

# %%
# your code here
# Out:
# businesses
# <class 'list'>
#
#
# total
# <class 'int'>
#
#
# region
# <class 'dict'>

# %% [markdown]
# How many results did our query return?

# %%
print(data['total'])
# Out:
# 35
# 35

# %% [markdown]
# How many businesses were returned from the API call?

# %%
print(len(data['businesses']))
# Out:
# 35

# %%
data['businesses']
# Out:
# [{'id': 'vlQwCfdPrgT6w-Xho_4xrA',
#   'alias': 'nonnaz-pizzeria-and-restaurant-queens-2',
#   'name': 'Nonnaz Pizzeria & Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1JDYBjxNnFuMLVSwM-3E6w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nonnaz-pizzeria-and-restaurant-queens-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 7,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.760154, 'longitude': -73.9074865},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '49-14 30th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Queens',
#    'zip_code': '11377',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['49-14 30th Ave', 'Queens, NY 11377']},
#   'phone': '+17188061165',
#   'display_phone': '(718) 806-1165',
#   'distance': 5600.473558725632},
#  {'id': '9KcKA_gwfqWuCG9Ln14P7A',
#   'alias': 'public-display-of-affection-brooklyn',
#   'name': 'Public Display of Affection',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RnTZ5IUYylDsPBtcwsDSDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/public-display-of-affection-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 13,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.67741, 'longitude': -73.98265},
#   'transactions': [],
#   'location': {'address1': '669 Union St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['669 Union St', 'Brooklyn, NY 11215']},
#   'phone': '+17186351678',
#   'display_phone': '(718) 635-1678',
#   'distance': 12486.602934614824},
#  {'id': 'IbTOahV7PjkYwVDsGlfseA',
#   'alias': 'margari-pizza-new-york',
#   'name': 'Margari Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9S76679FYDwFYKuiS3SWiw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/margari-pizza-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 6,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.758785, 'longitude': -73.965338},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1072 2nd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1072 2nd Ave', 'New York, NY 10022']},
#   'phone': '+12129061929',
#   'display_phone': '(212) 906-1929',
#   'distance': 9953.192520367458},
#  {'id': 'R-ve5GRzP0WlbQvDVI3HKg',
#   'alias': 'pane-pasta-new-york',
#   'name': 'Pane Pasta',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_2CPyMfrbo26gQX2lKFQ3Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pane-pasta-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 1,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.73328, 'longitude': -73.99905},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '58 West 8th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['58 West 8th St', 'New York, NY 10011']},
#   'phone': '+16468910006',
#   'display_phone': '(646) 891-0006',
#   'distance': 12323.11481665062},
#  {'id': 'qj-5zKQ1D4SuRCG3wSzd0g',
#   'alias': 'japan-pizza-den-den-gyoza-sunnyside',
#   'name': 'Japan Pizza Den Den Gyoza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ab0CfNB8hV0IqOqQHSCY7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/japan-pizza-den-den-gyoza-sunnyside?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 3,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'gourmet', 'title': 'Specialty Food'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.7427046910303,
#    'longitude': -73.9224605740662},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '43-48 42nd St',
#    'address2': '',
#    'address3': None,
#    'city': 'Sunnyside',
#    'zip_code': '11104',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['43-48 42nd St', 'Sunnyside, NY 11104']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 5997.080223139142},
#  {'id': 'e4L0hsq6Q96mV2nKQ9CgNQ',
#   'alias': 'tramonti-fifth-ave-new-york-2',
#   'name': 'Tramonti Fifth Ave',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-WR7y4TvoCAeM1147XW0Xg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tramonti-fifth-ave-new-york-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 11,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.74475, 'longitude': -73.98772},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'location': {'address1': '2 W 28th St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2 W 28th St', 'New York, NY 10001']},
#   'phone': '+12124647082',
#   'display_phone': '(212) 464-7082',
#   'distance': 11458.836657637006},
#  {'id': 'PORcMv0MUV-8DLM6tpk-wg',
#   'alias': 'hangry-new-hyde-park',
#   'name': 'Hangry',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bKCV7FiIQRgmA52sqMo6Fg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hangry-new-hyde-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 60,
#   'categories': [{'alias': 'halal', 'title': 'Halal'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.742781, 'longitude': -73.695043},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '725 Hillside Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New Hyde Park',
#    'zip_code': '11040',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['725 Hillside Ave', 'New Hyde Park, NY 11040']},
#   'phone': '+15166297102',
#   'display_phone': '(516) 629-7102',
#   'distance': 13354.719294850565},
#  {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#   'alias': 'rome-to-brooklyn-pizza-and-panzerotti-new-york',
#   'name': 'Rome to Brooklyn, pizza & panzerotti',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kK0siIAWk4yPMmCCjvp5wQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-and-panzerotti-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 21,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.711921, 'longitude': -73.942922},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '755 grand st',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['755 grand st', 'New York, NY 11211']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 7894.965119908428},
#  {'id': 'BQSPAXJcPw-7Gt2CCrH2Yw',
#   'alias': 'ita-italian-kitchen-jersey-city-2',
#   'name': 'Ita Italian Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3O1x-ptrFbqBCbH5qYNGPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ita-italian-kitchen-jersey-city-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 17,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.723524, 'longitude': -74.07016},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '686 Bergen Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Jersey City',
#    'zip_code': '07304',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['686 Bergen Ave', 'Jersey City, NJ 07304']},
#   'phone': '+12014358380',
#   'display_phone': '(201) 435-8380',
#   'distance': 18341.86544344835},
#  {'id': 'wOBPzCalMjGMxbifFatsrw',
#   'alias': 'il-bel-paese-brooklyn',
#   'name': 'IL Bel Paese',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Lk8eNCjIgG9O0iz8_I2noA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/il-bel-paese-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 3,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7017599753781,
#    'longitude': -73.9233199506998},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '305 Knickerbocker Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['305 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'phone': '+17186280077',
#   'display_phone': '(718) 628-0077',
#   'distance': 6796.355578126075},
#  {'id': 'IUuxH8Q7ek2465F6ENe43A',
#   'alias': 'taco-bell-rego-park',
#   'name': 'Taco Bell',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zYDCAmFt9sMpelq_6XZrFg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-bell-rego-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 10,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7296059198506, 'longitude': -73.862450234592},
#   'transactions': ['delivery'],
#   'location': {'address1': '9506 63rd Drive',
#    'address2': '',
#    'address3': None,
#    'city': 'Rego Park',
#    'zip_code': '11374',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9506 63rd Drive', 'Rego Park, NY 11374']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 835.4287450997344},
#  {'id': 'qZ364R1u7E3l6WotUOkLnQ',
#   'alias': 'pie-oh-my-woodland-park',
#   'name': 'PIE OH MY',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zk9odKulwewOQH9o-cf9aQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pie-oh-my-woodland-park?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 3,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.8837, 'longitude': -74.20366},
#   'transactions': [],
#   'location': {'address1': None,
#    'address2': None,
#    'address3': '',
#    'city': 'Woodland Park',
#    'zip_code': '07424',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['Woodland Park, NJ 07424']},
#   'phone': '+17186449490',
#   'display_phone': '(718) 644-9490',
#   'distance': 34513.70210634626},
#  {'id': '4oMi-MeyN1dVt-zuEMqdTQ',
#   'alias': 'mani-in-pasta-new-york-3',
#   'name': 'Mani In Pasta',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DEz4TXBia9BVwkBExPsdwg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mani-in-pasta-new-york-3?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 2,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.754887, 'longitude': -73.98962},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '231 W 39th St',
#    'address2': '',
#    'address3': 'The Deco',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['231 W 39th St', 'The Deco', 'New York, NY 10018']},
#   'phone': '+16469931650',
#   'display_phone': '(646) 993-1650',
#   'distance': 11813.435213401595},
#  {'id': 'eendqrZ9Cp_JisaDtoBU4w',
#   'alias': 'bravo-pizza-staten-island',
#   'name': 'Bravo Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/98GIefvXOn22c6qrv3ebMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bravo-pizza-staten-island?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 11,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.5701278126894, 'longitude': -74.108795389156},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '413  New Dorp Ln',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['413  New Dorp Ln', 'Staten Island, NY 10306']},
#   'phone': '+17183171010',
#   'display_phone': '(718) 317-1010',
#   'distance': 28072.918509476836},
#  {'id': 'WBG-l_bfLmBwR0P36ZFOLg',
#   'alias': 'hong-chun-cheon-cheese-dak-galbi-flushing',
#   'name': 'Hong Chun Cheon Cheese Dak galbi',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZLBf8cSLR-woCBrGiE5cRQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hong-chun-cheon-cheese-dak-galbi-flushing?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 13,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7638809, 'longitude': -73.808914},
#   'transactions': [],
#   'location': {'address1': '156-16 Northern Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Flushing',
#    'zip_code': '11354',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['156-16 Northern Blvd', 'Flushing, NY 11354']},
#   'phone': '+17188881844',
#   'display_phone': '(718) 888-1844',
#   'distance': 5113.620883228562},
#  {'id': '-KRZr8qtXaJF7gVL-xrM6w',
#   'alias': 'uncle-louies-pizza-montvale',
#   'name': "Uncle Louie's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lQ13dvw_VGpbjnTtI2-Fzw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/uncle-louies-pizza-montvale?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 4,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wraps', 'title': 'Wraps'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.040611, 'longitude': -74.031044},
#   'transactions': [],
#   'location': {'address1': '15 W Grand Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Montvale',
#    'zip_code': '07645',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['15 W Grand Ave', 'Montvale, NJ 07645']},
#   'phone': '+12017469777',
#   'display_phone': '(201) 746-9777',
#   'distance': 37496.707932827536},
#  {'id': 'ihpr2et12Z1eqDd94oLzbg',
#   'alias': 'papi-white-plains',
#   'name': "Papi'",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/htul4laoxg_xNeS1ArLNsA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/papi-white-plains?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 17,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.0316366, 'longitude': -73.7741697},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Bank St',
#    'address2': None,
#    'address3': None,
#    'city': 'White Plains',
#    'zip_code': '10606',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Bank St', 'White Plains, NY 10606']},
#   'phone': '+19143286535',
#   'display_phone': '(914) 328-6535',
#   'distance': 34026.440444961256},
#  {'id': 'gzRYzr57wh8NmvySbFAioQ',
#   'alias': 'pulia-ristorante-brooklyn-3',
#   'name': 'Pulia Ristorante',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_8l8yDlW2p-6pt-vVJl3lA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pulia-ristorante-brooklyn-3?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 8,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6669558, 'longitude': -73.9918603},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'location': {'address1': '548 4th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['548 4th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+17187881140',
#   'display_phone': '(718) 788-1140',
#   'distance': 13740.312546433044},
#  {'id': 'z0lX40tXQxOHlU26VhLATA',
#   'alias': 'american-brass-long-island-city',
#   'name': 'American Brass',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3L2vmRGaTRNGq1pJfMrFSQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/american-brass-long-island-city?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 8,
#   'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7439708, 'longitude': -73.958493},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '49th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Long Island City',
#    'zip_code': '11109',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['49th Ave', 'Long Island City, NY 11109']},
#   'phone': '+17188061106',
#   'display_phone': '(718) 806-1106',
#   'distance': 9009.156580274745},
#  {'id': 'kQvwxbFuvRMoj7G5SkmoCw',
#   'alias': 'i-love-panzerotti-east-village-new-york',
#   'name': 'I Love Panzerotti-- East Village',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dWbavKg5sxQDT3HAsU3dzw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/i-love-panzerotti-east-village-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 8,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.7266801, 'longitude': -73.9835791},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '130 St Marks Pl',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['130 St Marks Pl', 'New York, NY 10009']},
#   'phone': '+16465967113',
#   'display_phone': '(646) 596-7113',
#   'distance': 11029.061040158234},
#  {'id': '9qAI3zpjQPL2cf4ak41iGQ',
#   'alias': 'saige-cafe-at-le-havre-whitestone',
#   'name': 'Saige Cafe At Le Havre',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aPJ0BEQysLSP0VZ37bdz8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/saige-cafe-at-le-havre-whitestone?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 1,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.7926827, 'longitude': -73.796176},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '168-68 9th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Whitestone',
#    'zip_code': '11357',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['168-68 9th Ave', 'Whitestone, NY 11357']},
#   'phone': '+19179941978',
#   'display_phone': '(917) 994-1978',
#   'distance': 8316.227229899267},
#  {'id': 'vwXTY710wucZYxWjxhoQlw',
#   'alias': 'public-pizza-italian-kitchen-yonkers',
#   'name': 'Public Pizza Italian Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y-PlP_VjlPxIior2q2NUgQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/public-pizza-italian-kitchen-yonkers?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 14,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.965286, 'longitude': -73.857319},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '193 Market St',
#    'address2': '',
#    'address3': None,
#    'city': 'Yonkers',
#    'zip_code': '10710',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['193 Market St', 'Yonkers, NY 10710']},
#   'phone': '+19146527611',
#   'display_phone': '(914) 652-7611',
#   'distance': 26002.333618676646},
#  {'id': '7vqKC--s8iJ37QGitNhkeQ',
#   'alias': 'zanmi-brooklyn-2',
#   'name': 'Zanmi',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gjnAYbEfInQrdx1rsTlNSQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zanmi-brooklyn-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 18,
#   'categories': [{'alias': 'haitian', 'title': 'Haitian'},
#    {'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.6579395, 'longitude': -73.9505773},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1206 Nostrand Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11225',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1206 Nostrand Ave', 'Brooklyn, NY 11225']},
#   'phone': '+17186761047',
#   'display_phone': '(718) 676-1047',
#   'distance': 11607.511952493971},
#  {'id': 'bfTN46ZuFean1ahYVE3s9Q',
#   'alias': 'the-marilyn-new-york',
#   'name': 'The Marilyn',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p75Yt7HDI0k1KQcJZxr-nQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-marilyn-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 13,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.747222, 'longitude': -73.98699},
#   'transactions': [],
#   'location': {'address1': '19 W 31st St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 W 31st St', 'New York, NY 10001']},
#   'phone': '+12126159900',
#   'display_phone': '(212) 615-9900',
#   'distance': 11436.370552586292},
#  {'id': '41l-WTeRkc6dy6Zss9MG4w',
#   'alias': 'six-corners-marketplace-new-york',
#   'name': 'Six Corners Marketplace',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JE3Y0FEsmmbURc_OIzY45g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/six-corners-marketplace-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 6,
#   'categories': [{'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'grocery', 'title': 'Grocery'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.80125, 'longitude': -73.9681801},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '2755 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2755 Broadway', 'New York, NY 10025']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 12433.801215294208},
#  {'id': '3ip8E1YiD6jiIF51-oaXiw',
#   'alias': 'tavola-della-nonna-new-york',
#   'name': 'Tavola Della Nonna',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xo96dq6IQZpcUg3eBtC9YA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tavola-della-nonna-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 13,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.77757, 'longitude': -73.98347},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '208 W 70th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10023',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['208 W 70th St', 'New York, NY 10023']},
#   'phone': '+12128758600',
#   'display_phone': '(212) 875-8600',
#   'distance': 12123.812431360613},
#  {'id': 'cF-dEjuELf-m4CWN9zFhjw',
#   'alias': 'taco-bell-cantina-new-york-13',
#   'name': 'Taco Bell Cantina',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NVmP1AJiSk2C7WsEx1v8gg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-bell-cantina-new-york-13?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 6,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.750926, 'longitude': -73.986737},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '976 6th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['976 6th Ave', 'New York, NY 10018']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 11485.921543759065},
#  {'id': 'hUf1EpnxbxFU4gf2nL7H-Q',
#   'alias': 'raku-its-japanese-new-york-2',
#   'name': "Raku it's Japanese",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sYcYRWpDHeP0wRBeF-HMjg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/raku-its-japanese-new-york-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 16,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.756591, 'longitude': -73.969306},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '212 East 52nd St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['212 East 52nd St', 'New York, NY 10022']},
#   'phone': '+12123553272',
#   'display_phone': '(212) 355-3272',
#   'distance': 10202.14607573553},
#  {'id': 'jFEGRmuZe5fwCugyZnBmyg',
#   'alias': 'exotic-empanadas-new-york',
#   'name': 'Exotic Empanadas',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6LgmV1-cKE6JNFY3jVDaLg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/exotic-empanadas-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 9,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'soup', 'title': 'Soup'},
#    {'alias': 'empanadas', 'title': 'Empanadas'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.74528, 'longitude': -73.97574},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '635 2nd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['635 2nd Ave', 'New York, NY 10016']},
#   'phone': '+16467070488',
#   'display_phone': '(646) 707-0488',
#   'distance': 10470.87090567895},
#  {'id': 'L949I6aMoUEpaY-dr-SJNw',
#   'alias': 'dragon-sushi-new-york',
#   'name': 'Dragon Sushi',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zDYIgyz7NHLDg7g5nGie9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dragon-sushi-new-york?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 9,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.811043, 'longitude': -73.958387},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1264 Amsterdam Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1264 Amsterdam Ave', 'New York, NY 10027']},
#   'phone': '+16464905254',
#   'display_phone': '(646) 490-5254',
#   'distance': 12543.618965750353},
#  {'id': '3Z95QwfXtxOUdPRjiSVtFw',
#   'alias': 'amira-s-steak-and-chops-hicksville',
#   'name': 'Amira’s Steak & Chops',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7TAK8n1hbu6dWWTU2bophg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/amira-s-steak-and-chops-hicksville?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 7,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.75889, 'longitude': -73.513534},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '412 S Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Hicksville',
#    'zip_code': '11801',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['412 S Broadway', 'Hicksville, NY 11801']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 28746.823378405454},
#  {'id': '7MPabjQRvQ_IhD3Wfmf-cQ',
#   'alias': 'anna-marias-wine-bar-rye',
#   'name': "Anna Maria's Wine Bar",
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/anna-marias-wine-bar-rye?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 6,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'tapas', 'title': 'Tapas Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.98354, 'longitude': -73.68513},
#   'transactions': [],
#   'location': {'address1': '53 Purchase St',
#    'address2': None,
#    'address3': None,
#    'city': 'Rye',
#    'zip_code': '10580',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['53 Purchase St', 'Rye, NY 10580']},
#   'phone': '+19143056780',
#   'display_phone': '(914) 305-6780',
#   'distance': 31386.18836335289},
#  {'id': 'e5c8jGklVNKoaURcDsVxgQ',
#   'alias': 'curry-up-now-hoboken',
#   'name': 'Curry Up Now',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L2ei7yoBaDnEndYWuA2d0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/curry-up-now-hoboken?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 58,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.737095, 'longitude': -74.030759},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '91 Washington St',
#    'address2': None,
#    'address3': '',
#    'city': 'Hoboken',
#    'zip_code': '07030',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['91 Washington St', 'Hoboken, NJ 07030']},
#   'phone': '+12016592879',
#   'display_phone': '(201) 659-2879',
#   'distance': 15003.41880110369},
#  {'id': 'tCZWXOnv_6R7GbmzVAUgHg',
#   'alias': 'something-sweet-brooklyn',
#   'name': 'Something Sweet',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOmTtDaWLS-EZzI-ftbEng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/something-sweet-brooklyn?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 6,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.604613, 'longitude': -73.998727},
#   'transactions': [],
#   'location': {'address1': '1976 86th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11214',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1976 86th St', 'Brooklyn, NY 11214']},
#   'phone': '+17185177337',
#   'display_phone': '(718) 517-7337',
#   'distance': 18719.933183671368},
#  {'id': 'SNTBdiEi55Zvt3qa4AAEJg',
#   'alias': 'sakana-sushi-and-hibachi-steakhouse-staten-island',
#   'name': 'Sakana Sushi & Hibachi Steakhouse',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2A3iBAhvVfunyW8L8KmZGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sakana-sushi-and-hibachi-steakhouse-staten-island?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#   'review_count': 13,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.589737938998, 'longitude': -74.1013584556552},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1657 Richmond Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10304',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1657 Richmond Rd', 'Staten Island, NY 10304']},
#   'phone': '+17189877999',
#   'display_phone': '(718) 987-7999',
#   'distance': 26225.480961449095}]

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][0]

# %%
business
# Out:
# {'id': 'vlQwCfdPrgT6w-Xho_4xrA',
#  'alias': 'nonnaz-pizzeria-and-restaurant-queens-2',
#  'name': 'Nonnaz Pizzeria & Restaurant',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1JDYBjxNnFuMLVSwM-3E6w/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/nonnaz-pizzeria-and-restaurant-queens-2?adjust_creative=iiD4cWOR-Fz3fX4le1knTg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iiD4cWOR-Fz3fX4le1knTg',
#  'review_count': 7,
#  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.760154, 'longitude': -73.9074865},
#  'transactions': ['pickup', 'delivery'],
#  'location': {'address1': '49-14 30th Ave',
#   'address2': None,
#   'address3': '',
#   'city': 'Queens',
#   'zip_code': '11377',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['49-14 30th Ave', 'Queens, NY 11377']},
#  'phone': '+17188061165',
#  'display_phone': '(718) 806-1165',
#  'distance': 5600.473558725632}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_list = [business['name'], 
            ', '.join(business['location']['display_address']), 
            business['display_phone']]

# %%
biz_list
# Out:
# ['Nonnaz Pizzeria & Restaurant',
#  '49-14 30th Ave, Queens, NY 11377',
#  '(718) 806-1165']

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of lists with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    parsed_data = []
    
    # loop through our business and parse each individual business
    for business in list_of_data:
        print(business['name'])
        biz_list = [business['name'], 
            ', '.join(business['location']['display_address']), 
            business['display_phone']]
    # in the loop, add each individual parsed  business to our data container
        parsed_data.append(biz_list)

    # return the container with all of the parsed results
    return parsed_data

# %%
parsed_data=parse_data(data['businesses'])
# Out:
# Nonnaz Pizzeria & Restaurant
# Public Display of Affection
# Margari Pizza
# Pane Pasta
# Japan Pizza Den Den Gyoza
# Tramonti Fifth Ave
# Hangry
# Rome to Brooklyn, pizza & panzerotti
# Ita Italian Kitchen
# IL Bel Paese
# Taco Bell
# PIE OH MY
# Mani In Pasta
# Bravo Pizza
# Hong Chun Cheon Cheese Dak galbi
# Uncle Louie's Pizza
# Papi'
# Pulia Ristorante
# American Brass
# I Love Panzerotti-- East Village
# Saige Cafe At Le Havre
# Public Pizza Italian Kitchen
# Zanmi
# The Marilyn
# Six Corners Marketplace
# Tavola Della Nonna
# Taco Bell Cantina
# Raku it's Japanese
# Exotic Empanadas
# Dragon Sushi
# Amira’s Steak & Chops
# Anna Maria's Wine Bar
# Curry Up Now
# Something Sweet
# Sakana Sushi & Hibachi Steakhouse

# %%
import pandas as pd

# %%
cols=['Name','Adress','Phone']

# %%
df=pd.DataFrame(parsed_data, columns=cols)

# %%
df.to_csv('yelp_biz_data.csv')
